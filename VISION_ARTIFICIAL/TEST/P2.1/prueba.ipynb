# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('C:/5TO_UPIIT/VISION_ARTIFICIAL/VA/VISION_ARTIFICIAL/IMAGES/chiquita.jpg', 0)
img1 = np.copy(image)
plt.imshow(img1, cmap='gray')

# %%
#from VISION_ARTIFICIAL.FUNCIONES.UTILIDADES import funciones
import sys
sys.path.append('/5TO_UPIIT/VISION_ARTIFICIAL/VA/VISION_ARTIFICIAL/FUNCIONES/FORMAS_BINARIAS')

from componentes_conectados import componentes
b = componentes(img1)
plt.imshow(b, cmap='rainbow')
