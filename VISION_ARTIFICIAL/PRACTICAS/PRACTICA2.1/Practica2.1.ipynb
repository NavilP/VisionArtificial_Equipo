# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('C:/5TO_UPIIT/VISION_ARTIFICIAL/VA/VISION_ARTIFICIAL/IMAGES/chiquita.jpg', 0)
img1 = np.copy(image)
plt.imshow(img1, cmap='gray')

# %%
from FUNCIONES.UTILIDADES.funciones import suavizado
a = suavizado(img1)
plt.imshow(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\5TO_UPIIT\VISION_ARTIFICIAL\VA\VISION_ARTIFICIAL\PRACTICAS\PRACTICA2.1\Practica2.1.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/5TO_UPIIT/VISION_ARTIFICIAL/VA/VISION_ARTIFICIAL/PRACTICAS/PRACTICA2.1/Practica2.1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from FUNCIONES.UTILIDADES.funciones import suavizado
#       <a href='vscode-notebook-cell:/c%3A/5TO_UPIIT/VISION_ARTIFICIAL/VA/VISION_ARTIFICIAL/PRACTICAS/PRACTICA2.1/Practica2.1.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> a = suavizado(img1)
#       <a href='vscode-notebook-cell:/c%3A/5TO_UPIIT/VISION_ARTIFICIAL/VA/VISION_ARTIFICIAL/PRACTICAS/PRACTICA2.1/Practica2.1.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(a)
#
# ModuleNotFoundError: No module named 'FUNCIONES'
