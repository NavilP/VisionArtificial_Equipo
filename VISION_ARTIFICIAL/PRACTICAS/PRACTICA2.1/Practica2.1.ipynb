# %% [markdown]
# # Segmentación por crecimiento de región

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Abrir imagen
image = cv2.imread('../../IMAGES/mri.jpg', 0)
img = np.copy(image)
plt.imshow(img1, cmap='gray')

# %%
import sys
sys.path.append('../../FUNCIONES/SEGMENTACION')
from crecimiento_region import seg_region

seed_x, seed_y = 150, 150
threshold = 70

segmentacion = seg_region(img, (seed_x,seed_y), threshold)

plt.imshow(segmentacion, cmap='gray')

# %% [markdown]
# # Segmentación por cluster por el método de k-medias
